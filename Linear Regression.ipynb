# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("housing_dataset.csv")

# %%
df.head()
# Out:
#    Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0     1  114300  1790         2          2       2    No         East
# 1     2  114200  2030         4          2       3    No         East
# 2     3  114800  1740         3          2       1    No         East
# 3     4   94700  1980         3          2       3    No         East
# 4     5  119800  2130         3          3       3    No         East

# %%
df.isnull().sum()
# Out:
# Home            0
# Price           0
# SqFt            0
# Bedrooms        0
# Bathrooms       0
# Offers          0
# Brick           0
# Neighborhood    0
# dtype: int64

# %%
df.shape
# Out:
# (128, 8)

# %%
df
# Out:
#      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0       1  114300  1790         2          2       2    No         East
# 1       2  114200  2030         4          2       3    No         East
# 2       3  114800  1740         3          2       1    No         East
# 3       4   94700  1980         3          2       3    No         East
# 4       5  119800  2130         3          3       3    No         East
# ..    ...     ...   ...       ...        ...     ...   ...          ...
# 123   124  119700  1900         3          3       3   Yes         East
# 124   125  147900  2160         4          3       3   Yes         East
# 125   126  113500  2070         2          2       2    No        North
# 126   127  149900  2020         3          3       1    No         West
# 127   128  124600  2250         3          3       4    No        North
#
# [128 rows x 8 columns]

# %% [markdown]
# ### Data cleaning

# %%
 df.drop(columns=['Offers', 'Brick', 'Neighborhood'],inplace=True)

# %%
df
# Out:
#      Home   Price  SqFt  Bedrooms  Bathrooms
# 0       1  114300  1790         2          2
# 1       2  114200  2030         4          2
# 2       3  114800  1740         3          2
# 3       4   94700  1980         3          2
# 4       5  119800  2130         3          3
# ..    ...     ...   ...       ...        ...
# 123   124  119700  1900         3          3
# 124   125  147900  2160         4          3
# 125   126  113500  2070         2          2
# 126   127  149900  2020         3          3
# 127   128  124600  2250         3          3
#
# [128 rows x 5 columns]

# %%
df.drop(columns=['Home'],inplace=True)

# %%
df
# Out:
#       Price  SqFt  Bedrooms  Bathrooms
# 0    114300  1790         2          2
# 1    114200  2030         4          2
# 2    114800  1740         3          2
# 3     94700  1980         3          2
# 4    119800  2130         3          3
# ..      ...   ...       ...        ...
# 123  119700  1900         3          3
# 124  147900  2160         4          3
# 125  113500  2070         2          2
# 126  149900  2020         3          3
# 127  124600  2250         3          3
#
# [128 rows x 4 columns]

# %% [markdown]
# ### Independent and dependent features

# %%
X= df[['SqFt', 'Bedrooms', 'Bathrooms']]

# %%
y= df['Price']

# %%
X
# Out:
#      SqFt  Bedrooms  Bathrooms
# 0    1790         2          2
# 1    2030         4          2
# 2    1740         3          2
# 3    1980         3          2
# 4    2130         3          3
# ..    ...       ...        ...
# 123  1900         3          3
# 124  2160         4          3
# 125  2070         2          2
# 126  2020         3          3
# 127  2250         3          3
#
# [128 rows x 3 columns]

# %%
np.array(X).shape
# Out:
# (128, 3)

# %%
np.array(y).shape
# Out:
# (128,)

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split (X,y,test_size=0.25, random_state =42)

# %%
X_train
# Out:
#      SqFt  Bedrooms  Bathrooms
# 126  2020         3          3
# 24   2210         4          3
# 67   2040         4          3
# 111  1740         2          2
# 89   2010         2          2
# ..    ...       ...        ...
# 106  2130         3          2
# 14   2590         4          3
# 92   2110         3          2
# 51   1860         2          2
# 102  2410         3          3
#
# [96 rows x 3 columns]

# %%
y_train
# Out:
# 126    149900
# 24     156400
# 67     151900
# 111    114900
# 89      97800
#         ...
# 106    108500
# 14     176800
# 92     142600
# 51      91100
# 102    136800
# Name: Price, Length: 96, dtype: int64

# %%
X_train.shape
# Out:
# (96, 3)

# %%
y_train.shape
# Out:
# (96,)

# %% [markdown]
# ### Standarization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.0478753 , -0.11396058,  0.96076892],
#        [ 0.95750607,  1.25356634,  0.96076892],
#        [ 0.14362591,  1.25356634,  0.96076892],
#        [-1.2926332 , -1.48148749, -0.96076892],
#        [ 0.        , -1.48148749, -0.96076892],
#        [-1.10113198,  1.25356634, -0.96076892],
#        [ 1.2926332 ,  1.25356634,  0.96076892],
#        [-1.53200972, -0.11396058, -0.96076892],
#        [-0.33512713, -0.11396058,  0.96076892],
#        [-2.681017  , -1.48148749, -0.96076892],
#        [-0.19150121, -1.48148749, -0.96076892],
#        [ 1.14900729,  1.25356634,  0.96076892],
#        [ 1.00538138,  1.25356634,  0.96076892],
#        [-0.38300243, -0.11396058,  0.96076892],
#        [-1.3405085 , -0.11396058,  0.96076892],
#        [ 1.2926332 ,  2.62109326,  0.96076892],
#        [ 0.95750607, -0.11396058,  0.96076892],
#        [ 1.3405085 ,  1.25356634,  0.96076892],
#        [-0.52662834, -0.11396058,  0.96076892],
#        [-1.96288745, -1.48148749, -0.96076892],
#        [-0.0478753 , -1.48148749, -0.96076892],
#        [ 0.67025425, -0.11396058, -0.96076892],
#        [ 0.43087773, -0.11396058, -0.96076892],
#        [-1.10113198, -0.11396058, -0.96076892],
#        [ 0.62237895, -0.11396058, -0.96076892],
#        [ 0.14362591, -0.11396058,  0.96076892],
#        [-1.2926332 , -0.11396058, -0.96076892],
#        [-1.48413441, -0.11396058, -0.96076892],
#        [ 0.33512713, -0.11396058,  0.96076892],
#        [ 0.86175546, -0.11396058,  0.96076892],
#        [ 0.23937652, -1.48148749, -0.96076892],
#        [-0.0478753 , -1.48148749, -0.96076892],
#        [ 1.14900729,  1.25356634,  0.96076892],
#        [ 0.71812955,  1.25356634, -0.96076892],
#        [-0.43087773, -0.11396058, -0.96076892],
#        [-0.38300243, -0.11396058, -0.96076892],
#        [-0.33512713, -1.48148749, -0.96076892],
#        [-0.09575061, -0.11396058,  0.96076892],
#        [ 0.47875304,  1.25356634, -0.96076892],
#        [ 0.67025425, -0.11396058,  0.96076892],
#        [ 0.33512713, -0.11396058,  0.96076892],
#        [-0.14362591, -0.11396058, -0.96076892],
#        [-0.09575061, -0.11396058,  0.96076892],
#        [-1.3883838 , -0.11396058, -0.96076892],
#        [-1.72351093, -0.11396058, -0.96076892],
#        [ 0.        , -0.11396058, -0.96076892],
#        [-0.86175546, -0.11396058,  0.96076892],
#        [ 1.91501214, -0.11396058,  0.96076892],
#        [-1.43625911, -1.48148749, -0.96076892],
#        [-0.43087773, -1.48148749, -0.96076892],
#        [-1.72351093, -0.11396058, -0.96076892],
#        [ 0.43087773, -0.11396058, -0.96076892],
#        [-0.43087773, -0.11396058, -0.96076892],
#        [-0.09575061, -1.48148749,  0.96076892],
#        [-0.52662834, -0.11396058,  0.96076892],
#        [-1.91501214, -1.48148749, -0.96076892],
#        [ 0.71812955,  1.25356634,  0.96076892],
#        [-1.10113198,  1.25356634, -0.96076892],
#        [ 1.19688259, -0.11396058,  0.96076892],
#        [-0.81388016,  1.25356634,  0.96076892],
#        [-0.81388016, -0.11396058,  0.96076892],
#        [-0.43087773,  1.25356634, -0.96076892],
#        [-0.14362591, -1.48148749, -0.96076892],
#        [-0.38300243, -0.11396058,  0.96076892],
#        [ 0.47875304, -0.11396058, -0.96076892],
#        [ 1.10113198,  1.25356634,  0.96076892],
#        [-0.52662834, -1.48148749, -0.96076892],
#        [ 1.14900729, -0.11396058,  0.96076892],
#        [-0.38300243, -1.48148749,  0.96076892],
#        [ 0.38300243,  1.25356634, -0.96076892],
#        [-0.47875304, -1.48148749,  0.96076892],
#        [-0.57450364, -0.11396058, -0.96076892],
#        [ 1.96288745,  1.25356634,  0.96076892],
#        [ 0.14362591,  1.25356634,  0.96076892],
#        [ 0.        ,  1.25356634,  0.96076892],
#        [ 0.09575061,  1.25356634, -0.96076892],
#        [ 0.67025425, -1.48148749,  0.96076892],
#        [-0.0478753 , -0.11396058, -0.96076892],
#        [-1.2926332 , -0.11396058, -0.96076892],
#        [-0.90963077, -0.11396058, -0.96076892],
#        [ 2.05863805,  1.25356634,  0.96076892],
#        [ 0.33512713, -0.11396058,  0.96076892],
#        [-0.62237895, -0.11396058,  0.96076892],
#        [ 1.3405085 ,  2.62109326,  2.88230677],
#        [ 0.62237895, -0.11396058,  0.96076892],
#        [-0.52662834,  1.25356634, -0.96076892],
#        [ 0.19150121, -1.48148749, -0.96076892],
#        [ 1.14900729, -0.11396058,  0.96076892],
#        [-1.05325668, -0.11396058, -0.96076892],
#        [ 0.90963077, -0.11396058,  0.96076892],
#        [ 0.71812955,  1.25356634, -0.96076892],
#        [ 0.57450364, -0.11396058, -0.96076892],
#        [ 2.77676761,  1.25356634,  0.96076892],
#        [ 0.47875304, -0.11396058, -0.96076892],
#        [-0.71812955, -1.48148749, -0.96076892],
#        [ 1.91501214, -0.11396058,  0.96076892]])

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Apply Simple linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([9531.59006298, 7624.85109685, 5433.58476214])

# %%
model.intercept_
# Out:
# np.float64(131618.75)

# %% [markdown]
# ### Training Data best fit line

# %%
X_train.shape
# Out:
# (96, 3)

# %%
y_train.shape
# Out:
# (96,)

# %% [markdown]
# ### Prediction for test data

# %%
y_predict = model.predict (X_test)

# %% [markdown]
# ### performance matrix

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score

# %%
MSE = mean_squared_error(y_test, y_predict)
MAE = mean_absolute_error(y_test, y_predict)
Score = r2_score(y_test, y_predict)

# %%
print(MSE)
# Out:
# 359055280.1906175

# %%
print(MAE)
# Out:
# 15518.953485723323

# %%
print(Score)
# Out:
# 0.41428156294959395

# %%
print(feature)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 print(feature)
#
# NameError: name 'feature' is not defined
